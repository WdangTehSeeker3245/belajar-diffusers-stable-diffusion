# %%
# !pip install git+https://github.com/huggingface/diffusers
# Out:
# ...
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-fq24b07t
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-fq24b07t
#   Resolved https://github.com/huggingface/diffusers to commit 080081bdeda61a4723a61594f9f1c12909d695b7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 12.3 MB/s eta 0:00:00
# ...
#   Created wheel for diffusers: filename=diffusers-0.22.0.dev0-py3-none-any.whl size=1635156 sha256=10df6f6785c7486b3fad10babb2c170bf6e61a3f742a5b5174444c5fbada9aa6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ht0twoox/wheels/f7/7d/99/d361489e5762e3464b3811bc629e94cf5bf5ef44dd5c3c4d52
# Successfully built diffusers
# ...

# %%
# !git clone https://github.com/huggingface/diffusers.git
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 44116, done.
# remote: Counting objects: 100% (1634/1634), done.
# remote: Compressing objects: 100% (476/476), done.
# remote: Total 44116 (delta 1225), reused 1404 (delta 1036), pack-reused 42482
# Receiving objects: 100% (44116/44116), 28.48 MiB | 19.52 MiB/s, done.
# Resolving deltas: 100% (32680/32680), done.

# %%
# !pip install -r /content/diffusers/examples/text_to_image/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 36.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 42.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 93.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 39.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.18.0
#     Uninstalling huggingface-hub-0.18.0:
#       Successfully uninstalled huggingface-hub-0.18.0
# ...

# %%
# !cp /content/diffusers/examples/text_to_image/train_text_to_image_lora.py /content/train_text_to_image_lora.py

# %%
# !accelerate config default
# Out:
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %%
# !pip install wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 25.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.6 MB/s eta 0:00:00
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=fbaa405733d1e184975cf743c75c1c9d659f9b0b2ea20f9a02ac79e819eed754
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# ...

# %%
# !pip install bitsandbytes
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.6 MB/s eta 0:00:00
# ...

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from huggingface_hub import snapshot_download
snapshot_download(repo_id="faizalnf1800/sidebags-earring-anime-woman-lora-stingermix", local_dir="/content/sidebags-earring-anime-woman-lora-stingermix")

# %%
# !accelerate launch --mixed_precision="fp16"  train_text_to_image_lora.py \
  --pretrained_model_name_or_path="faizalnf1800/StingerMix-v3.0-Full-SD1.5" \
  --dataset_name="faizalnf1800/sidebags_hairstyle_and_earring_anime_woman" \
  --dataloader_num_workers=8 \
  --resolution=512  \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=1000 \
  --learning_rate=1e-4 \
  --max_grad_norm=1 \
  --lr_scheduler="cosine" --lr_warmup_steps=500 \
  --output_dir="sidebags-earring-anime-woman-lora-stingermix" \
  --push_to_hub \
  --hub_model_id="sidebags-earring-anime-woman-lora-stingermix" \
  --report_to=wandb \
  --checkpointing_steps=500 \
  --validation_prompt="beautiful anime woman with sidebags hairstyle and earring" \
  --caption_column="additional_feature" \
  --seed=1337 \
  --use_8bit_adam
# Out:
# 11/05/2023 08:01:42 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# ...
# {'clip_sample_range'} was not found in config. Values will be initialized to default values.
# ...
# {'reverse_transformer_layers_per_block'} was not found in config. Values will be initialized to default values.
# ...
# Extracting data files: 100% 1/1 [00:00<00:00, 1138.52it/s]
# Generating train split: 100% 70/70 [00:00<00:00, 1013.02 examples/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !accelerate launch --mixed_precision="fp16"  train_text_to_image_lora.py \
  --pretrained_model_name_or_path="faizalnf1800/StingerMix-v3.0-Full-SD1.5" \
  --dataset_name="faizalnf1800/sidebags_hairstyle_and_earring_anime_woman" \
  --dataloader_num_workers=8 \
  --resolution=512  \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=2000 \
  --learning_rate=1e-4 \
  --max_grad_norm=1 \
  --lr_scheduler="cosine" --lr_warmup_steps=500 \
  --output_dir="sidebags-earring-anime-woman-lora-stingermix" \
  --push_to_hub \
  --hub_model_id="sidebags-earring-anime-woman-lora-stingermix" \
  --report_to=wandb \
  --checkpointing_steps=500 \
  --validation_prompt="beautiful anime woman with sidebags hairstyle and earring" \
  --caption_column="additional_feature" \
  --seed=1337 \
  --use_8bit_adam \
  --resume_from_checkpoint="checkpoint-1000"
# Out:
# 11/05/2023 08:22:35 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# {'clip_sample_range'} was not found in config. Values will be initialized to default values.
# {'reverse_transformer_layers_per_block'} was not found in config. Values will be initialized to default values.
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# ...

# %%
import os

# Specify the directory path where you want to delete .png files
directory_path = "/content"

# Iterate through the files in the directory
for filename in os.listdir(directory_path):
    if filename.endswith(".png"):
        file_path = os.path.join(directory_path, filename)
        os.remove(file_path)
        print(f"Deleted: {file_path}")
# Out:
# Deleted: /content/image20-2.png
# Deleted: /content/image10-0.png
# Deleted: /content/image0-3.png
# Deleted: /content/image50-1.png
# Deleted: /content/image10-2.png
# Deleted: /content/image30-3.png
# Deleted: /content/image40-0.png
# Deleted: /content/image0-2.png
# Deleted: /content/image20-1.png
# Deleted: /content/image50-2.png
# Deleted: /content/image20-3.png
# Deleted: /content/image40-2.png
# Deleted: /content/image50-0.png
# Deleted: /content/image20-0.png
# Deleted: /content/image50-3.png
# Deleted: /content/image40-3.png
# Deleted: /content/image30-0.png
# Deleted: /content/image30-2.png
# Deleted: /content/image10-1.png
# Deleted: /content/image0-0.png
# Deleted: /content/image30-1.png
# Deleted: /content/image40-1.png
# Deleted: /content/image0-1.png
# Deleted: /content/image10-3.png

# %%
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained("faizalnf1800/StingerMix-v4.0-SD1.5")

# %%
pipe.load_lora_weights("faizalnf1800/sidebags-earring-anime-woman-lora")
pipe.to("cuda")
pipe.safety_checker = None
pipe.requires_safety_checker = False

# %%
prompt = "A woman have long black hair with side bags hair style and wear earring."
image = pipe(prompt, num_inference_steps=30, guidance_scale=7.5).images[0]
image.save("image.png")

# %%
from huggingface_hub import upload_folder

output_dir = "/content/sidebags-earring-anime-woman-lora"
hub_model_id = "faizalnf1800/sidebags-earring-anime-woman-lora"

upload_folder(output_dir, hub_model_id)

# %%
import torch

# Convert the model to safetensors format
pipe.to_safetensors()

# Save the safetensors file
torch.save(pipe, "sidebags-earring-anime-woman-lora.safetensors")
